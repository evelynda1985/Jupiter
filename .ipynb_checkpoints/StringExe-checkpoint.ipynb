# %%
m = 100
print (str(m) + ' days')
# Out:
# 100 days

# %%
print("It's cool, isn't it?")
# Out:
# It's cool, isn't it?

# %%
'Don\'t be shy'
# Out:
# "Don't be shy"

# %%
print('Click "OK"')
# Out:
# Click "OK"

# %%
print("Big", "Houses")
# Out:
# Big Houses
