# %%
a = True
type(a)
# Out:
# bool

# %%
b = 99
type(b)
# Out:
# int

# %%
c = 0.99
type(c)
# Out:
# float

# %%
type(0.99)
# Out:
# float

# %%
b = 99
c = float(b)
print(c)
# Out:
# 99.0

# %%
int(0.99)
# Out:
# 0
