# %% [markdown]
# <a href="https://colab.research.google.com/github/evelynda1985/DataScience/blob/master/sklearnMultipleLinearRegressionExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Linear Regression with sklearn - Exercise Solution

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size_year.csv'.
#
# You are expected to create a multiple linear regression (similar to the one in the lecture), using the new data.
#
# Apart from that, please:
# -  Display the intercept and coefficient(s)
# -  Find the R-squared and Adjusted R-squared
# -  Compare the R-squared and the Adjusted R-squared
# -  Compare the R-squared of this regression and the simple linear regression where only 'size' was used
# -  Using the model make a prediction about an apartment with size 750 sq.ft. from 2009
# -  Find the univariate (or multivariate if you wish - see the article) p-values of the two variables. What can you say about them?
# -  Create a summary table with your findings
#
# In this exercise, the dependent variable is 'price', while the independent variables are 'size' and 'year'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load the data

# %%
import google.colab
google.colab.files.upload()
# Out:
#      <input type="file" id="files-fa200fc7-cd1b-4112-99b2-29c740b5061c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa200fc7-cd1b-4112-99b2-29c740b5061c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('real_estate_price_size_year.csv')
data
# Out:
#          price     size  year
# 0   234314.144   643.09  2015
# 1   228581.528   656.22  2009
# 2   281626.336   487.29  2018
# 3   401255.608  1504.75  2015
# 4   458674.256  1275.46  2009
# ..         ...      ...   ...
# 95  252460.400   549.80  2009
# 96  310522.592  1037.44  2009
# 97  383635.568  1504.75  2006
# 98  225145.248   648.29  2015
# 99  274922.856   705.29  2006
#
# [100 rows x 3 columns]

# %%
data.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
y = data['price']
x = data[['size','year']]

# %% [markdown]
# ### Regression

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Find the intercept

# %%
reg.intercept_
# Out:
# np.float64(-5772267.017463279)

# %% [markdown]
# ### Find the coefficients

# %%
reg.coef_
# Out:
# array([ 227.70085401, 2916.78532684])

# %% [markdown]
# ### Calculate the R-squared

# %%
reg.score(x,y)
# Out:
# 0.7764803683276795

# %% [markdown]
# ### Calculate the Adjusted R-squared

# %%
x.shape
# Out:
# (100, 2)

# %%
r2 = reg.score(x,y)
n = x.shape[0]
p = x.shape[1]
adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
adjusted_r2
# Out:
# 0.7718717161282502

# %% [markdown]
# ### Compare the R-squared and the Adjusted R-squared

# %% [markdown]
# Answer...
#  R-squared = 0.7764803683276795
#  Adjusted R-squared = 0.7718717161282502
#  Because is Multiple Linear Regression the most important value is the Adjusted R-squared, and 70% for me not bad
# BUT R-square is a lighter bigger than adjusted R-squared, it means we are not penalize for the use of the new variable

# %% [markdown]
# ### Compare the Adjusted R-squared with the R-squared of the simple linear regression

# %% [markdown]
# Answer...
# Multiple Linear Regression R-squared = 0.7764803683276795
# Simple Linear Regression R-squared = 0.7447391865847586
# The difference is not that much, it means there is not much difference with the new variable

# %% [markdown]
# ### Making predictions
#
# Find the predicted price of an apartment that has a size of 750 sq.ft. from 2009.

# %%
reg.predict([[750,2009]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([258330.34465995])

# %% [markdown]
# ### Calculate the univariate p-values of the variables

# %%
from sklearn.feature_selection import f_regression
f_regression(x,y)
# Out:
# (array([285.92105192,   0.85525799]), array([8.12763222e-31, 3.57340758e-01]))

# %%
p_values = f_regression(x,y)[1]
p_values
# Out:
# array([8.12763222e-31, 3.57340758e-01])

# %%
p_values.round(3)
# Out:
# array([0.   , 0.357])

# %% [markdown]
# ### Create a summary table with your findings

# %%
reg_summary = pd.DataFrame(data = x.columns.values, columns=['Features'])
# Out:
#   Features
# 0     size
# 1     year

# %%
reg_summary ['Coefficients'] = reg.coef_
reg_summary ['p-values'] = p_values.round(3)
reg_summary
# Out:
#   Features  Coefficients  p-values
# 0     size    227.700854     0.000
# 1     year   2916.785327     0.357

# %% [markdown]
# Answer... year is not significant for the model, it should be remove
