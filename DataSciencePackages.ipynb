# %%
import numpy as np #Multidimensional arrays and large data
import pandas as pd #Organize data and able to attach label
import scipy # Contains tools for math, machine learning, engineering
import statsmodels.api as sm #summaries
import matplotlib as plt #2D library to visualize NumPy 
import seaborn as sns #visualization high level of matplotlib
import sklearn #machine learning library, to install conda install scikit-learn

#to check what you have install open anaconda promt and 
# conda list
# To install
# conda install (package name)
